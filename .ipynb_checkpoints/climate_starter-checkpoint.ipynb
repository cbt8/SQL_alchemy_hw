# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
inspector = inspect(engine)

inspector.get_table_names()

stationcolumns = inspector.get_columns('station')
measurementcolumns = inspector.get_columns('measurement')

# %%
for c in stationcolumns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
for c in measurementcolumns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
#dt.datetime.today().strftime('%Y-%m-%d')

# Design a query to retrieve the last 12 months of precipitation data and plot the results

# %%
enddate = str(session.query(Measurement.date).order_by(Measurement.date.desc()).first())

# %%
enddate
# Out:
# "('2017-08-23',)"

# %%
#Note: I know there is a better way to input this date into the dt.date() formula, but I went for the easy way here. Also,
#2016 was a leap year, but 2017 was not, so the 365 is correct here. 



# Calculate the date 1 year ago from the last data point in the database


query_date = dt.date(2017, 8, 23) - dt.timedelta(days=365)
print("Query Date: ", query_date)
# Out:
# Query Date:  2016-08-23

# %%
#My original code did not include the order_by, but I have noticed that the months of november and december 
#were not properly arranged. 
#I ordered the session so that these work.

# Perform a query to retrieve the data and precipitation scores

recentyear = session.query(Measurement.date, Measurement.prcp).order_by(Measurement.date.desc()).\
    filter(Measurement.date > query_date).all()

# %%
recentyear[-1]
# Out:
# ('2016-08-24', 1.45)

# %%
recentdate = []
recentprcp = []

for i in recentyear:
    x, y = i
    recentdate.append(dt.datetime.strptime(x, '%Y-%m-%d')), recentprcp.append(y)

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
type(recentdate[1])

recentdf = pd.DataFrame(recentyear)

# %%
recentdf = recentdf.set_index(recentdf['date'])
recent2df = pd.DataFrame(recentdf['prcp'])

# %%
recent2df = recent2df.sort_index(axis = 0, ascending = True)

# %%
# Sort the dataframe by date
#Note: This dataframe appears to be already sorted by date, because of the way I called the session query. 
#The date does go in reverse chronological order, however. 
#However, I have done it here for completion. 

# Use Pandas Plotting with Matplotlib to plot the data

#Below was the original way I did this, which required less coding. It does not use a dataframe, just two lists. 

fig, ax = plt.subplots()
plt.plot(recentdate, recentprcp)
plt.ylabel("Precipitation in inches")

#This way is better, because it requires less code, is sorted properly, and does not require explicit changes to the x-axis.
# Out:
# Text(0,0.5,'Precipitation in inches')

# %%
#I also did the following way, for completion's sake
fig, ax = plt.subplots()
plt.plot(recent2df.index.values, recent2df['prcp'])
plt.ylabel("Precipitation in inches")
plt.xticks(['2016-09-01', '2017-01-01', '2017-05-01', '2017-09-01'])

#Note: The x-tick placement is kind of arbitary, just did what looked good. 

plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data

#Here it makes sense why it is in a dataframe:

recent2df.describe()
# Out:
#               prcp
# count  2015.000000
# mean      0.176462
# std       0.460288
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %%
# Design a query to show how many stations are available in this dataset?
len(session.query(func.count(Measurement.station)).group_by(Measurement.station).all())
# Out:
# 9

# %%
#This might be easier to understand by going one step down:

session.query(func.count(Measurement.station)).group_by(Measurement.station).all()

#This gives a list with the number of observations at each station. We use len() to count the number of stations.
# Out:
# [(1979), (2709), (2202), (2612), (1372), (511), (2772), (2724), (2669)]

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.

session.query(Measurement.station,func.count(Measurement.station)).group_by(Measurement.station)\
.order_by(func.count(Measurement.station).desc()).all()


#Same as above, but returning a tuple with the station name.
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?


session.query(Measurement.station, func.min(Measurement.tobs), func.max(Measurement.tobs),\
func.avg(Measurement.tobs), func.count(Measurement.station)).group_by(Measurement.station)\
.order_by(func.count(Measurement.station).desc()).all()


#In the respective order asked for:
# Out:
# [('USC00519281', 54.0, 85.0, 71.66378066378067, 2772),
#  ('USC00519397', 56.0, 87.0, 74.55323054331865, 2724),
#  ('USC00513117', 59.0, 85.0, 72.68918420081211, 2709),
#  ('USC00519523', 56.0, 85.0, 74.5436493068565, 2669),
#  ('USC00516128', 58.0, 84.0, 70.91500765696784, 2612),
#  ('USC00514830', 58.0, 85.0, 74.8732970027248, 2202),
#  ('USC00511918', 53.0, 87.0, 71.61596766043456, 1979),
#  ('USC00517948', 58.0, 87.0, 74.68440233236151, 1372),
#  ('USC00518838', 58.0, 83.0, 72.72407045009784, 511)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

#session.query(Measurement.station == 'USC00519281', Measurement.tobs)



tempdf = pd.DataFrame(session.query(Measurement.date, Measurement.tobs).order_by(Measurement.date.desc()).\
    filter(Measurement.date > query_date).filter(Measurement.station == 'USC00519281').all())

fig, ax = plt.subplots()
plt.hist(tempdf['tobs'])
plt.ylabel("Frequency")
plt.xlabel("Temperature")
# Out:
# Text(0.5,0,'Temperature')

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.

triptemp = calc_temps('2016-09-28', '2016-10-01')

print(triptemp[0][1])

type(triptemp[0][1])
# Out:
# 78.18518518518519
# float

# %%
bar = [triptemp[0][1]]
error=[triptemp[0][0], triptemp[0][2]]

x_axis = np.arange(0, len(bar), 1)

type(x_axis)

type(error)
# Out:
# list

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)


fig, ax = plt.subplots()
plt.errorbar( x_axis, bar, yerr= np.array([error]), fmt="ko")
plt.ylabel("Temperature")
plt.title("Trip Avg Temp")
plt.show()

# %%
# Calculate the rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

session.query(Measurement.station, Measurement.prcp, Station.name, Station.latitude, Station.longitude, Station.elevation)\
.group_by(Measurement.prcp)\
.filter(Measurement.station==Station.station)\
.order_by((Measurement.prcp).desc()).all()
# Out:
# [('USC00514830',
#   11.53,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281',
#   9.64,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   8.81,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   8.06,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   7.97,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117', 7.65, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   6.83,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   6.7,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   6.42,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523',
#   6.38,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00518838', 6.3, 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00519523',
#   6.25,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519281',
#   6.24,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117', 5.98, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   5.96,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 5.71, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519281',
#   5.54,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   5.37,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   5.35,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523',
#   5.32,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00513117', 5.21, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   5.09,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   5.04,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523',
#   4.95,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00513117', 4.94, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00513117', 4.88, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   4.81,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523',
#   4.76,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00519281',
#   4.68,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117', 4.6, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   4.56,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 4.47, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00513117', 4.43, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   4.32,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   4.3,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519397', 4.2, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128',
#   4.18,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   4.07,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   4.03,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 4.02, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   4.01,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   4.0,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   3.99,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00514830',
#   3.91,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281',
#   3.88,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   3.86,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00514830',
#   3.85,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00516128',
#   3.79,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   3.7,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   3.68,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   3.62,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00514830',
#   3.6,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281',
#   3.53,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00514830',
#   3.48,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519281',
#   3.47,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   3.46,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00511918',
#   3.44,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00519523',
#   3.43,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00516128',
#   3.4,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   3.38,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   3.35,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00514830',
#   3.33,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00513117', 3.3, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   3.27,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   3.26,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   3.23,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 3.18, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   3.14,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   3.1,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   3.06,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   3.05,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 3.03, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   3.01,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00511918',
#   3.0,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00516128',
#   2.98,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.97,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   2.96,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117', 2.95, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   2.92,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.9,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.87,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   2.86,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   2.84,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00511918',
#   2.83,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00516128',
#   2.82,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.81,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.8,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.79,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   2.77,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   2.75,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523',
#   2.71,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00518838', 2.7, 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00519281',
#   2.69,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   2.67,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.64,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.63,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519397', 2.62, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128',
#   2.61,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 2.6, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   2.59,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.57,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.56,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00514830',
#   2.55,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00516128',
#   2.5,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   2.49,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   2.48,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.47,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.46,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.45,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.44,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00514830',
#   2.43,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00519397', 2.42, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128',
#   2.41,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.4,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   2.39,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   2.37,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519523',
#   2.36,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00513117', 2.35, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00519281',
#   2.33,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519281',
#   2.32,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   2.31,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.3,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   2.29,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519523',
#   2.28,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00516128',
#   2.27,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.26,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.25,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.24,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.23,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.21,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.2,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.17,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.15,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.14,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.13,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.12,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.11,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00518838', 2.1, 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  ('USC00516128',
#   2.09,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.07,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 2.06, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   2.05,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.03,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   2.02,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00514830',
#   2.01,
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0),
#  ('USC00516128',
#   2.0,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519397', 1.98, 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  ('USC00516128',
#   1.97,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.96,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   1.95,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00519523',
#   1.94,
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5),
#  ('USC00516128',
#   1.92,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.91,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.9,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.89,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.88,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   1.87,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   1.86,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.85,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.84,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.83,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.82,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.81,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.8,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.79,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00513117', 1.78, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   1.77,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   1.76,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   1.75,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   1.74,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   1.73,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.72,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.71,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.7,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.69,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.68,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00511918',
#   1.67,
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9),
#  ('USC00516128',
#   1.66,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.65,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.62,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.61,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.6,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.59,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.58,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.57,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.56,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   1.55,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00513117', 1.54, 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  ('USC00516128',
#   1.53,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.52,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.51,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.5,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.49,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.48,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.47,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.46,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.45,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.44,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.43,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.42,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.41,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.4,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   1.39,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   1.38,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.37,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.36,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.35,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.34,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.33,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.32,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.31,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.3,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.29,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.28,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.27,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.26,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.25,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.24,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.23,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.22,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.21,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.2,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.19,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.18,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   1.17,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   1.16,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.15,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.14,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.13,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.12,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.11,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.1,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.09,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.08,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00519281',
#   1.07,
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9),
#  ('USC00516128',
#   1.06,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.05,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.04,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.03,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.02,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.01,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   1.0,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.99,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.98,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.97,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.96,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.95,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.94,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.93,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.92,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.91,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.9,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.89,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.88,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.87,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.86,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.85,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.84,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.83,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.82,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.81,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.8,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.79,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.78,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.77,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.76,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.75,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.74,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.73,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.72,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.71,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.7,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.69,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.68,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.67,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.66,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.65,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.64,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.63,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.62,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.61,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.6,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.59,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.58,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.57,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.56,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.55,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.54,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.53,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.52,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.51,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.5,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.49,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.48,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.47,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.46,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.45,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.44,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.43,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.42,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.41,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.4,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.39,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.38,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.37,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.36,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.35,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.34,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.33,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.32,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.31,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.3,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.29,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.28,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.27,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.26,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.25,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.24,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.23,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.22,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.21,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.2,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.19,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.18,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.17,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.16,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.15,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.14,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.13,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.12,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.11,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.1,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.09,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.08,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.07,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.06,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.05,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.04,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.03,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.02,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.01,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   0.0,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4),
#  ('USC00516128',
#   None,
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4)]

# %% [markdown]
# ## Optional Challenge Assignment

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

# %%
# Plot the daily normals as an area plot with `stacked=False`
